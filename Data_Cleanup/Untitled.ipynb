# %%
import pandas as pd
import numpy as np
import os
import sys
import glob
import read_legends as rlg
# Out:
# code_legends_fn_list
# ['/Users/vuthaiha/Documents/datathon/Oct_2019_Citadel/table_headers/code_legends/immigrant_legend.csv', '/Users/vuthaiha/Documents/datathon/Oct_2019_Citadel/table_headers/code_legends/soc_code_legend.csv', '/Users/vuthaiha/Documents/datathon/Oct_2019_Citadel/table_headers/code_legends/onet_code_legend.csv', '/Users/vuthaiha/Documents/datathon/Oct_2019_Citadel/table_headers/code_legends/labor_market_stats_legend.csv']
#
# code_legends_name_list
# ['immigrant_legend', 'soc_code_legend', 'onet_code_legend', 'labor_market_stats_legend']

# %% [markdown]
# # IMMIGRANT_LEGEND

# %%
print rlg.immigrant_code_df
# Out:
#         code                  geo_region                         nationality
# 0        AFN                Africa North                  Total Africa North
# 1        AFS          Africa Sub-Saharan            Total Africa Sub-Saharan
# 2      AFN.1               America North                 Total America North
# 3        ACS  America Central and South    Total America Central and South
# 4        ACE                Asia Central                  Total Asia Central
# 5        AEA                   Asia East                     Total Asia East
# 6        ASO                  Asia South                    Total Asia South
# 7        ASE             Asia South East               Total Asia South East
# 8        EU1                       EU 14                         Total EU 14
# 9        EU2                        EU 2                          Total EU 2
# 10       EU8                        EU 8                          Total EU 8
# ...

# %% [markdown]
# # SOC_CODE

# %%
print rlg.soc_code_df
# Out:
#      major  sub_major  minor    unit  \
# 0      1.0        NaN    NaN     NaN
# 1      1.0       11.0    NaN     NaN
# 2      1.0       11.0  111.0     NaN
# 3      1.0       11.0  111.0  1115.0
# 4      1.0       11.0  111.0  1116.0
# 5      1.0       11.0  112.0     NaN
# 6      1.0       11.0  112.0  1121.0
# 7      1.0       11.0  112.0  1122.0
# 8      1.0       11.0  112.0  1123.0
# 9      1.0       11.0  113.0     NaN
# 10     1.0       11.0  113.0  1131.0
# 11     1.0       11.0  113.0  1132.0
# 12     1.0       11.0  113.0  1133.0
# 13     1.0       11.0  113.0  1134.0
# 14     1.0       11.0  113.0  1135.0
# 15     1.0       11.0  113.0  1136.0
# 16     1.0       11.0  113.0  1139.0
# 17     1.0       11.0  115.0     NaN
# 18     1.0       11.0  115.0  1150.0
# 19     1.0       11.0  116.0     NaN
# 20     1.0       11.0  116.0  1161.0
# 21     1.0       11.0  116.0  1162.0
# 22     1.0       11.0  117.0     NaN
# 23     1.0       11.0  117.0  1171.0
# ...

# %%
#print (helper.soc_code_df['Unit   Group']).unique()

# %% [markdown]
# # ONET_CODE

# %%
print rlg.onet_code_df
# Out:
#             code                                              title  \
# 0     11-1011.00                                   Chief Executives
# 1     11-1011.03                      Chief Sustainability Officers
# 2     11-1021.00                    General and Operations Managers
# 3     11-1031.00                                        Legislators
# 4     11-2011.00                Advertising and Promotions Managers
# 5     11-2011.01                                    Green Marketers
# 6     11-2021.00                                 Marketing Managers
# 7     11-2022.00                                     Sales Managers
# 8     11-2031.00          Public Relations and Fundraising Managers
# 9     11-3011.00                   Administrative Services Managers
# 10    11-3021.00          Computer and Information Systems Managers
# 11    11-3031.00                                 Financial Managers
# 12    11-3031.01                         Treasurers and Controllers
# ...

# %% [markdown]
# # LABOR MARKET STATISTICS CODE

# %%
print rlg.labor_market_code_df
# Out:
#                                                  Title  CDID   Unit
# 0    LFS: Economically active: UK: Male: Aged 50-64...  YBZY  000's
# 1    LFS: Economically active: UK: All: Aged 25-34:...  YBZR  000's
# 2    LFS: Economically active: UK: Female: Aged 18-...  YBZQ  000's
# 3    LFS: Economically active: UK: Female: Aged 25-...  YBZT  000's
# 4    LFS: Economically active: UK: Male: Aged 25-34...  YBZS  000's
# 5    LFS: Economically active: UK: Male: Aged 35-49...  YBZV  000's
# 6    LFS: Economically active: UK: All: Aged 35-49:...  YBZU  000's
# 7    LFS: Economically active: UK: Female: Aged 35-...  YBZW  000's
# 8    UK Job Vacancies ratio per 100 emp jobs - Othe...  JPC3    NaN
# 9    UK Job Vacancies ratio per 100 emp jobs - Tota...  JPC4    NaN
# 10   UK Job Vacancies ratio per 100 emp jobs - Arts...  JPC2    NaN
# 11   Number of unemployed people per vacancy (UK ex...  JPC5    NaN
# 12   LFS: In employment: Aged 16-24: In full-time e...  AGNZ  000's
# ...
