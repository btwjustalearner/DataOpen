# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
labor_df = pd.read_csv('labor_market_statistics.csv')
date_df = pd.read_csv('econ.csv')
# labor_df = pd.merge(labor_df,date_df,how='left',left_on=['Year','Month'],right_on=['Year','Month'])
labor_df.head()
# Out:
#    Year Month     YBZY     YBZR     YBZQ     YBZT     YBZS     YBZV      YBZU  \
# 0  1992  YEAR  38376.0  88044.0  24636.0  37656.0  50388.0  64752.0  118176.0
# 1  1993  YEAR  38184.0  89076.0  23628.0  38556.0  50520.0  64968.0  119064.0
# 2  1994  YEAR  38400.0  89784.0  22248.0  39024.0  50772.0  65016.0  119376.0
# 3  1995  YEAR  38436.0  90072.0  21516.0  39492.0  50568.0  65604.0  120468.0
# 4  1996  YEAR  39192.0  89976.0  20952.0  39780.0  50184.0  65772.0  121524.0
#
#       YBZW  ...  LF3M  AIYW  LF3T  LF45    YCGN  AIYX  DZ36  LF3S  LF44  \
# 0  53424.0  ...  71.5   6.0  67.7  60.8  6072.0   6.6   NaN  71.3  57.9
# 1  54096.0  ...  70.8   5.2  67.5  60.8  6132.0   6.2   NaN  71.3  58.4
# 2  54360.0  ...  71.5   5.2  69.3  61.2  5568.0   6.1   NaN  70.5  57.0
# 3  54864.0  ...  71.4   5.2  69.8  60.3  5016.0   6.1   NaN  72.2  58.4
# 4  55752.0  ...  72.1   5.7  70.0  61.6  4656.0   6.8   NaN  72.9  58.5
#
#      YCGM
# 0  9264.0
# 1  9360.0
# 2  8592.0
# 3  7908.0
# ...

# %%
date_df.head()
# Out:
#    Year  Month  East Midlands  East of England  London  North East  \
# 0  2001      1           77.3             80.8    75.0        71.7
# 1  2001      2           77.1             80.9    75.0        71.4
# 2  2001      3           77.2             81.0    74.8        71.6
# 3  2001      4           77.4             80.7    74.6        71.8
# 4  2001      5           77.3             80.3    75.1        71.6
#
#    North West  Scotland  South East  South West  Wales  West Midlands  \
# 0        74.4      76.2        81.1        79.7   71.4           76.0
# 1        74.4      76.1        81.0        79.6   71.5           76.1
# 2        74.6      75.8        80.9        79.8   71.2           76.2
# 3        74.8      76.1        80.9        79.6   70.8           76.2
# 4        75.0      76.3        81.0        79.7   70.7           75.9
#
#    Yorks and Humber        date
# 0              76.4  2001-01-01
# 1              75.6  2001-02-01
# 2              75.7  2001-03-01
# ...

# %%
months=labor_df[9:21].Month
print(months)
# Out:
# 9     JAN
# 10    FEB
# 11    MAR
# 12    APR
# 13    MAY
# 14    JUN
# 15    JUL
# 16    AUG
# 17    SEP
# 18    OCT
# 19    NOV
# 20    DEC
# Name: Month, dtype: object

# %%
labor_wquarters=labor_df[labor_df.Month != 'YEAR']
labor_bymonth=df1[df1.Month.astype(str).str[0]!='Q']
# Out:
#     Year Month    YBZY    YBZR    YBZQ    YBZT    YBZS    YBZV     YBZU  \
# 9   2001   JAN  3661.0  7117.0  1710.0  3209.0  3908.0  5680.0  10605.0
# 10  2001   FEB  3665.0  7081.0  1708.0  3179.0  3902.0  5687.0  10613.0
# 11  2001   MAR  3674.0  7076.0  1724.0  3185.0  3891.0  5676.0  10606.0
# 12  2001   APR  3676.0  7064.0  1718.0  3182.0  3882.0  5669.0  10610.0
# 13  2001   MAY  3674.0  7062.0  1733.0  3183.0  3878.0  5659.0  10607.0
# 14  2001   JUN  3672.0  7027.0  1722.0  3159.0  3868.0  5669.0  10613.0
# 15  2001   JUL  3700.0  7000.0  1723.0  3149.0  3851.0  5670.0  10624.0
# 16  2001   AUG  3695.0  6996.0  1723.0  3146.0  3850.0  5689.0  10642.0
# 17  2001   SEP  3695.0  6988.0  1743.0  3144.0  3844.0  5695.0  10642.0
# 18  2001   OCT  3701.0  6973.0  1757.0  3138.0  3836.0  5694.0  10652.0
# 19  2001   NOV  3696.0  6953.0  1766.0  3125.0  3828.0  5707.0  10672.0
# 20  2001   DEC  3685.0  6948.0  1770.0  3121.0  3827.0  5711.0  10685.0
# ...

# %%
Agro = labor_bymonth.JPC5.dropna(0)
Arts = labor_bymonth.JPC2.dropna(0)
Arts.drop(Arts.tail(1).index,inplace=True)
Years = labor_bymonth.Year

# %%
length_of_data = len(Agro)
plt.plot(np.arange(length_of_data),Agro)
plt.plot(np.arange(length_of_data),Arts)

# %%
Arts.plot()

# %%
Agro.plot()
